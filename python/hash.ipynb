# %%
from python.data_structures.hash_table.hash_family.polynomial import PolynomialHashing
from hashlib import sha256, sha512, md5

string = 'this is my sample string'

hash_func = PolynomialHashing(10**20)
print("output of polynomial has family:", hash_func.hash('sala m'))
print("output of polynomial has family:",hash_func.hash('sala m'))
print("output of python hash function:",hash('hamed'))
print("output of md5 hash function:", md5('hamed'.encode()).hexdigest())
print("output of sha256 hash function:", sha256('hamed'.encode()).hexdigest())
print("output of sha512 hash function:", sha512('hamed'.encode()).hexdigest())
# Out:
# output of polynomial has family: 37173616415306888022
# output of polynomial has family: 37173616415306888022
# output of python hash function: 7018685141793121591
# output of md5 hash function: 739b7af086e8c8873d6c8c7378f224c8
# output of sha256 hash function: ce25fe351f2e98a1cdd39c09d5411a155f782b9745478b8342d7f86ee81ff4e6
# output of sha512 hash function: 296532ea6e3d31996ecff110a91a659875a44bd67056f31a31b1b8790d447a9d0c85edc41d8f5fdc3e1cfc10ea6393d0f01ef7ad8998b2486e5aee8966748c4a

# %%
# %%timeit

from python.data_structures.hash_table.map import HashTable

my_dict = HashTable()
my_dict['matin'] = 1
my_dict.get('matin')
# Out:
# Hashed index 839
# size of array 1000
# index 839
# size of array 1000
# index 839
# Hashed index 143
# size of array 1000
# index 143
# size of array 1000
# index 143
# Hashed index 351
# size of array 1000
# index 351
# size of array 1000
# index 351
# Hashed index 261
# size of array 1000
# index 261
# size of array 1000
# index 261
# Hashed index 923
# size of array 1000
# index 923
# size of array 1000
# index 923
# Hashed index 47
# size of array 1000
# index 47
# size of array 1000
# index 47
# Hashed index 179
# size of array 1000
# index 179
# size of array 1000
# index 179
# Hashed index 376
# size of array 1000
# index 376
# size of array 1000
# index 376
# Hashed index 789
# size of array 1000
# index 789
# size of array 1000
# index 789
# Hashed index 42
# size of array 1000
# index 42
# size of array 1000
# index 42
# Hashed index 548
# size of array 1000
# index 548
# size of array 1000
# index 548
# Hashed index 293
# size of array 1000
# index 293
# size of array 1000
# index 293
# Hashed index 213
# size of array 1000
# index 213
# size of array 1000
# index 213
# Hashed index 17
# size of array 1000
# index 17
# size of array 1000
# index 17
# Hashed index 291
# size of array 1000
# index 291
# size of array 1000
# index 291
# Hashed index 436
# size of array 1000
# index 436
# size of array 1000
# index 436
# Hashed index 769
# size of array 1000
# index 769
# size of array 1000
# index 769
# Hashed index 720
# size of array 1000
# index 720
# size of array 1000
# index 720
# Hashed index 809
# size of array 1000
# index 809
# size of array 1000
# index 809
# Hashed index 815
# size of array 1000
# index 815
# size of array 1000
# index 815
# Hashed index 205
# size of array 1000
# index 205
# size of array 1000
# index 205
# Hashed index 917
# size of array 1000
# index 917
# size of array 1000
# index 917
# Hashed index 239
# size of array 1000
# index 239
# size of array 1000
# index 239
# Hashed index 978
# size of array 1000
# index 978
# size of array 1000
# index 978
# Hashed index 915
# size of array 1000
# index 915
# size of array 1000
# index 915
# Hashed index 462
# size of array 1000
# index 462
# size of array 1000
# index 462
# Hashed index 381
# size of array 1000
# index 381
# size of array 1000
# index 381
# Hashed index 682
# size of array 1000
# index 682
# size of array 1000
# index 682
# Hashed index 154
# size of array 1000
# index 154
# size of array 1000
# index 154
# Hashed index 440
# size of array 1000
# index 440
# size of array 1000
# index 440
# Hashed index 825
# size of array 1000
# index 825
# size of array 1000
# index 825
# Hashed index 789
# size of array 1000
# index 789
# size of array 1000
# index 789
# Hashed index 587
# size of array 1000
# index 587
# size of array 1000
# index 587
# Hashed index 451
# size of array 1000
# index 451
# size of array 1000
# index 451
# Hashed index 222
# size of array 1000
# index 222
# size of array 1000
# index 222
# Hashed index 683
# size of array 1000
# index 683
# size of array 1000
# index 683
# Hashed index 260
# size of array 1000
# index 260
# size of array 1000
# index 260
# Hashed index 442
# size of array 1000
# index 442
# size of array 1000
# index 442
# Hashed index 928
# size of array 1000
# index 928
# size of array 1000
# index 928
# Hashed index 605
# size of array 1000
# index 605
# size of array 1000
# index 605
# Hashed index 473
# size of array 1000
# index 473
# size of array 1000
# index 473
# Hashed index 944
# size of array 1000
# index 944
# size of array 1000
# index 944
# Hashed index 73
# size of array 1000
# index 73
# size of array 1000
# index 73
# Hashed index 112
# size of array 1000
# index 112
# size of array 1000
# index 112
# Hashed index 745
# size of array 1000
# index 745
# size of array 1000
# index 745
# Hashed index 545
# size of array 1000
# index 545
# size of array 1000
# index 545
# Hashed index 427
# size of array 1000
# index 427
# size of array 1000
# index 427
# Hashed index 313
# size of array 1000
# index 313
# size of array 1000
# index 313
# Hashed index 139
# size of array 1000
# index 139
# size of array 1000
# index 139
# Hashed index 234
# size of array 1000
# index 234
# size of array 1000
# index 234
# Hashed index 373
# size of array 1000
# index 373
# size of array 1000
# index 373
# Hashed index 145
# size of array 1000
# index 145
# size of array 1000
# index 145
# Hashed index 599
# size of array 1000
# index 599
# size of array 1000
# index 599
# Hashed index 510
# size of array 1000
# index 510
# size of array 1000
# index 510
# Hashed index 983
# size of array 1000
# index 983
# size of array 1000
# index 983
# Hashed index 293
# size of array 1000
# index 293
# size of array 1000
# index 293
# Hashed index 314
# size of array 1000
# index 314
# size of array 1000
# index 314
# Hashed index 347
# size of array 1000
# index 347
# size of array 1000
# index 347
# Hashed index 490
# size of array 1000
# index 490
# size of array 1000
# index 490
# Hashed index 849
# size of array 1000
# index 849
# size of array 1000
# index 849
# Hashed index 804
# size of array 1000
# index 804
# size of array 1000
# index 804
# Hashed index 107
# size of array 1000
# index 107
# size of array 1000
# index 107
# Hashed index 296
# size of array 1000
# index 296
# size of array 1000
# index 296
# Hashed index 602
# size of array 1000
# index 602
# size of array 1000
# index 602
# Hashed index 858
# size of array 1000
# index 858
# size of array 1000
# index 858
# Hashed index 137
# size of array 1000
# index 137
# size of array 1000
# index 137
# Hashed index 675
# size of array 1000
# index 675
# size of array 1000
# index 675
# Hashed index 737
# size of array 1000
# index 737
# size of array 1000
# index 737
# Hashed index 272
# size of array 1000
# index 272
# size of array 1000
# index 272
# Hashed index 605
# size of array 1000
# index 605
# size of array 1000
# index 605
# Hashed index 780
# size of array 1000
# index 780
# size of array 1000
# index 780
# Hashed index 383
# size of array 1000
# index 383
# size of array 1000
# index 383
# Hashed index 699
# size of array 1000
# index 699
# size of array 1000
# index 699
# Hashed index 334
# size of array 1000
# index 334
# size of array 1000
# index 334
# Hashed index 456
# size of array 1000
# index 456
# size of array 1000
# index 456
# Hashed index 760
# size of array 1000
# index 760
# size of array 1000
# index 760
# Hashed index 330
# size of array 1000
# index 330
# size of array 1000
# index 330
# Hashed index 865
# size of array 1000
# index 865
# size of array 1000
# index 865
# Hashed index 163
# size of array 1000
# index 163
# size of array 1000
# index 163
# Hashed index 216
# size of array 1000
# index 216
# size of array 1000
# index 216
# Hashed index 249
# size of array 1000
# index 249
# size of array 1000
# index 249
# Hashed index 511
# size of array 1000
# index 511
# size of array 1000
# index 511
# Hashed index 839
# size of array 1000
# index 839
# size of array 1000
# index 839
# Hashed index 511
# size of array 1000
# index 511
# size of array 1000
# index 511
# Hashed index 916
# size of array 1000
# index 916
# size of array 1000
# index 916
# Hashed index 681
# size of array 1000
# index 681
# size of array 1000
# index 681
# Hashed index 918
# size of array 1000
# index 918
# size of array 1000
# index 918
# Hashed index 78
# size of array 1000
# index 78
# size of array 1000
# index 78
# Hashed index 38
# size of array 1000
# index 38
# size of array 1000
# index 38
# Hashed index 492
# size of array 1000
# index 492
# size of array 1000
# index 492
# Hashed index 243
# size of array 1000
# index 243
# size of array 1000
# index 243
# Hashed index 46
# size of array 1000
# index 46
# size of array 1000
# index 46
# Hashed index 870
# size of array 1000
# index 870
# size of array 1000
# index 870
# Hashed index 880
# size of array 1000
# index 880
# size of array 1000
# index 880
# Hashed index 744
# size of array 1000
# index 744
# size of array 1000
# index 744
# Hashed index 957
# size of array 1000
# index 957
# size of array 1000
# index 957
# Hashed index 975
# size of array 1000
# index 975
# size of array 1000
# index 975
# Hashed index 258
# size of array 1000
# index 258
# size of array 1000
# index 258
# Hashed index 834
# size of array 1000
# index 834
# size of array 1000
# index 834
# Hashed index 245
# size of array 1000
# index 245
# size of array 1000
# index 245
# Hashed index 770
# size of array 1000
# index 770
# size of array 1000
# index 770
# Hashed index 971
# size of array 1000
# index 971
# size of array 1000
# index 971
# Hashed index 230
# size of array 1000
# index 230
# size of array 1000
# index 230
# Hashed index 224
# size of array 1000
# index 224
# size of array 1000
# index 224
# Hashed index 535
# size of array 1000
# index 535
# size of array 1000
# index 535
# Hashed index 302
# size of array 1000
# index 302
# size of array 1000
# index 302
# Hashed index 968
# size of array 1000
# index 968
# size of array 1000
# index 968
# Hashed index 884
# size of array 1000
# index 884
# size of array 1000
# index 884
# Hashed index 701
# size of array 1000
# index 701
# size of array 1000
# index 701
# Hashed index 765
# size of array 1000
# index 765
# size of array 1000
# index 765
# Hashed index 444
# size of array 1000
# index 444
# size of array 1000
# index 444
# Hashed index 159
# size of array 1000
# index 159
# size of array 1000
# index 159
# Hashed index 415
# size of array 1000
# index 415
# size of array 1000
# index 415
# Hashed index 923
# size of array 1000
# index 923
# size of array 1000
# index 923
# Hashed index 490
# size of array 1000
# index 490
# size of array 1000
# index 490
# Hashed index 953
# size of array 1000
# index 953
# size of array 1000
# index 953
# Hashed index 630
# size of array 1000
# index 630
# size of array 1000
# index 630
# Hashed index 190
# size of array 1000
# index 190
# size of array 1000
# index 190
# Hashed index 750
# size of array 1000
# index 750
# size of array 1000
# index 750
# Hashed index 24
# size of array 1000
# index 24
# size of array 1000
# index 24
# Hashed index 261
# size of array 1000
# index 261
# size of array 1000
# index 261
# Hashed index 342
# size of array 1000
# index 342
# size of array 1000
# index 342
# Hashed index 197
# size of array 1000
# index 197
# size of array 1000
# index 197
# Hashed index 966
# size of array 1000
# index 966
# size of array 1000
# index 966
# Hashed index 436
# size of array 1000
# index 436
# size of array 1000
# index 436
# Hashed index 391
# size of array 1000
# index 391
# size of array 1000
# index 391
# Hashed index 436
# size of array 1000
# index 436
# size of array 1000
# index 436
# Hashed index 92
# size of array 1000
# index 92
# size of array 1000
# index 92
# Hashed index 166
# size of array 1000
# index 166
# size of array 1000
# index 166
# Hashed index 183
# size of array 1000
# index 183
# size of array 1000
# index 183
# Hashed index 264
# size of array 1000
# index 264
# size of array 1000
# index 264
# Hashed index 392
# size of array 1000
# index 392
# size of array 1000
# index 392
# Hashed index 484
# size of array 1000
# index 484
# size of array 1000
# index 484
# Hashed index 451
# size of array 1000
# index 451
# size of array 1000
# index 451
# Hashed index 188
# size of array 1000
# index 188
# size of array 1000
# index 188
# Hashed index 871
# size of array 1000
# index 871
# size of array 1000
# index 871
# Hashed index 192
# size of array 1000
# index 192
# size of array 1000
# index 192
# Hashed index 161
# size of array 1000
# index 161
# size of array 1000
# index 161
# Hashed index 808
# size of array 1000
# index 808
# size of array 1000
# index 808
# Hashed index 760
# size of array 1000
# index 760
# size of array 1000
# index 760
# Hashed index 419
# size of array 1000
# index 419
# size of array 1000
# index 419
# Hashed index 815
# size of array 1000
# index 815
# size of array 1000
# index 815
# Hashed index 863
# size of array 1000
# index 863
# size of array 1000
# index 863
# Hashed index 151
# size of array 1000
# index 151
# size of array 1000
# index 151
# Hashed index 299
# size of array 1000
# index 299
# size of array 1000
# index 299
# Hashed index 44
# size of array 1000
# index 44
# size of array 1000
# index 44
# Hashed index 535
# size of array 1000
# index 535
# size of array 1000
# index 535
# Hashed index 556
# size of array 1000
# index 556
# size of array 1000
# index 556
# Hashed index 542
# size of array 1000
# index 542
# size of array 1000
# index 542
# Hashed index 660
# size of array 1000
# index 660
# size of array 1000
# index 660
# Hashed index 497
# size of array 1000
# index 497
# size of array 1000
# index 497
# Hashed index 758
# size of array 1000
# index 758
# size of array 1000
# index 758
# Hashed index 544
# size of array 1000
# index 544
# size of array 1000
# index 544
# Hashed index 578
# size of array 1000
# index 578
# size of array 1000
# index 578
# Hashed index 418
# size of array 1000
# index 418
# size of array 1000
# index 418
# Hashed index 22
# size of array 1000
# index 22
# size of array 1000
# index 22
# Hashed index 823
# size of array 1000
# index 823
# size of array 1000
# index 823
# Hashed index 397
# size of array 1000
# index 397
# size of array 1000
# index 397
# Hashed index 519
# size of array 1000
# index 519
# size of array 1000
# index 519
# Hashed index 326
# size of array 1000
# index 326
# size of array 1000
# index 326
# Hashed index 15
# size of array 1000
# index 15
# size of array 1000
# index 15
# Hashed index 351
# size of array 1000
# index 351
# size of array 1000
# index 351
# Hashed index 410
# size of array 1000
# index 410
# size of array 1000
# index 410
# Hashed index 571
# size of array 1000
# index 571
# size of array 1000
# index 571
# Hashed index 553
# size of array 1000
# index 553
# size of array 1000
# index 553
# Hashed index 236
# size of array 1000
# index 236
# size of array 1000
# index 236
# Hashed index 715
# size of array 1000
# index 715
# size of array 1000
# index 715
# Hashed index 227
# size of array 1000
# index 227
# size of array 1000
# index 227
# Hashed index 646
# size of array 1000
# index 646
# size of array 1000
# index 646
# Hashed index 450
# size of array 1000
# index 450
# size of array 1000
# index 450
# Hashed index 112
# size of array 1000
# index 112
# size of array 1000
# index 112
# Hashed index 988
# size of array 1000
# index 988
# size of array 1000
# index 988
# Hashed index 299
# size of array 1000
# index 299
# size of array 1000
# index 299
# Hashed index 964
# size of array 1000
# index 964
# size of array 1000
# index 964
# Hashed index 808
# size of array 1000
# index 808
# size of array 1000
# index 808
# Hashed index 264
# size of array 1000
# index 264
# size of array 1000
# index 264
# Hashed index 631
# size of array 1000
# index 631
# size of array 1000
# index 631
# Hashed index 186
# size of array 1000
# index 186
# size of array 1000
# index 186
# Hashed index 332
# size of array 1000
# index 332
# size of array 1000
# index 332
# Hashed index 480
# size of array 1000
# index 480
# size of array 1000
# index 480
# Hashed index 878
# size of array 1000
# index 878
# size of array 1000
# index 878
# Hashed index 317
# size of array 1000
# index 317
# size of array 1000
# index 317
# Hashed index 369
# size of array 1000
# index 369
# size of array 1000
# index 369
# Hashed index 739
# size of array 1000
# index 739
# size of array 1000
# index 739
# Hashed index 379
# size of array 1000
# index 379
# size of array 1000
# index 379
# Hashed index 368
# size of array 1000
# index 368
# size of array 1000
# index 368
# Hashed index 344
# size of array 1000
# index 344
# size of array 1000
# index 344
# Hashed index 235
# size of array 1000
# index 235
# size of array 1000
# index 235
# Hashed index 903
# size of array 1000
# index 903
# size of array 1000
# index 903
# Hashed index 105
# size of array 1000
# index 105
# size of array 1000
# index 105
# Hashed index 703
# size of array 1000
# index 703
# size of array 1000
# index 703
# Hashed index 704
# size of array 1000
# index 704
# size of array 1000
# index 704
# Hashed index 909
# size of array 1000
# index 909
# size of array 1000
# index 909
# Hashed index 848
# size of array 1000
# index 848
# size of array 1000
# index 848
# Hashed index 375
# size of array 1000
# index 375
# size of array 1000
# index 375
# Hashed index 88
# size of array 1000
# index 88
# size of array 1000
# index 88
# Hashed index 854
# size of array 1000
# index 854
# size of array 1000
# index 854
# Hashed index 129
# size of array 1000
# index 129
# size of array 1000
# index 129
# Hashed index 888
# size of array 1000
# index 888
# size of array 1000
# index 888
# Hashed index 120
# size of array 1000
# index 120
# size of array 1000
# index 120
# Hashed index 875
# size of array 1000
# index 875
# size of array 1000
# index 875
# Hashed index 475
# size of array 1000
# index 475
# size of array 1000
# index 475
# Hashed index 261
# size of array 1000
# index 261
# size of array 1000
# index 261
# Hashed index 667
# size of array 1000
# index 667
# size of array 1000
# index 667
# Hashed index 8
# size of array 1000
# index 8
# size of array 1000
# index 8
# Hashed index 866
# size of array 1000
# index 866
# size of array 1000
# index 866
# Hashed index 486
# size of array 1000
# index 486
# size of array 1000
# index 486
# Hashed index 404
# size of array 1000
# index 404
# size of array 1000
# index 404
# Hashed index 875
# size of array 1000
# index 875
# size of array 1000
# index 875
# Hashed index 923
# size of array 1000
# index 923
# size of array 1000
# index 923
# Hashed index 930
# size of array 1000
# index 930
# size of array 1000
# index 930
# Hashed index 269
# size of array 1000
# index 269
# size of array 1000
# index 269
# Hashed index 730
# size of array 1000
# index 730
# size of array 1000
# index 730
# Hashed index 211
# size of array 1000
# index 211
# size of array 1000
# index 211
# Hashed index 811
# size of array 1000
# index 811
# size of array 1000
# index 811
# Hashed index 666
# size of array 1000
# index 666
# size of array 1000
# index 666
# Hashed index 859
# size of array 1000
# index 859
# size of array 1000
# index 859
# Hashed index 897
# size of array 1000
# index 897
# size of array 1000
# index 897
# Hashed index 594
# size of array 1000
# index 594
# size of array 1000
# index 594
# Hashed index 20
# size of array 1000
# index 20
# size of array 1000
# index 20
# Hashed index 175
# size of array 1000
# index 175
# size of array 1000
# index 175
# Hashed index 430
# size of array 1000
# index 430
# size of array 1000
# index 430
# Hashed index 333
# size of array 1000
# index 333
# size of array 1000
# index 333
# Hashed index 529
# size of array 1000
# index 529
# size of array 1000
# index 529
# Hashed index 359
# size of array 1000
# index 359
# size of array 1000
# index 359
# Hashed index 695
# size of array 1000
# index 695
# size of array 1000
# index 695
# Hashed index 783
# size of array 1000
# index 783
# size of array 1000
# index 783
# Hashed index 823
# size of array 1000
# index 823
# size of array 1000
# index 823
# Hashed index 950
# size of array 1000
# index 950
# size of array 1000
# index 950
# Hashed index 339
# size of array 1000
# index 339
# size of array 1000
# index 339
# Hashed index 365
# size of array 1000
# index 365
# size of array 1000
# index 365
# Hashed index 705
# size of array 1000
# index 705
# size of array 1000
# index 705
# Hashed index 936
# size of array 1000
# index 936
# size of array 1000
# index 936
# Hashed index 674
# size of array 1000
# index 674
# size of array 1000
# index 674
# Hashed index 403
# size of array 1000
# index 403
# size of array 1000
# index 403
# Hashed index 459
# size of array 1000
# index 459
# size of array 1000
# index 459
# Hashed index 406
# size of array 1000
# index 406
# size of array 1000
# index 406
# Hashed index 9
# size of array 1000
# index 9
# size of array 1000
# index 9
# Hashed index 160
# size of array 1000
# index 160
# size of array 1000
# index 160
# Hashed index 421
# size of array 1000
# index 421
# size of array 1000
# index 421
# Hashed index 739
# size of array 1000
# index 739
# size of array 1000
# index 739
# Hashed index 59
# size of array 1000
# index 59
# size of array 1000
# index 59
# Hashed index 674
# size of array 1000
# index 674
# size of array 1000
# index 674
# Hashed index 319
# size of array 1000
# index 319
# size of array 1000
# index 319
# Hashed index 140
# size of array 1000
# index 140
# size of array 1000
# index 140
# Hashed index 612
# size of array 1000
# index 612
# size of array 1000
# index 612
# Hashed index 810
# size of array 1000
# index 810
# size of array 1000
# index 810
# Hashed index 979
# size of array 1000
# index 979
# size of array 1000
# index 979
# Hashed index 526
# size of array 1000
# index 526
# size of array 1000
# index 526
# Hashed index 584
# size of array 1000
# index 584
# size of array 1000
# index 584
# Hashed index 593
# size of array 1000
# index 593
# size of array 1000
# index 593
# Hashed index 36
# size of array 1000
# index 36
# size of array 1000
# index 36
# Hashed index 531
# size of array 1000
# index 531
# size of array 1000
# index 531
# Hashed index 372
# size of array 1000
# index 372
# size of array 1000
# index 372
# Hashed index 10
# size of array 1000
# index 10
# size of array 1000
# index 10
# Hashed index 780
# size of array 1000
# index 780
# size of array 1000
# index 780
# Hashed index 787
# size of array 1000
# index 787
# size of array 1000
# index 787
# Hashed index 260
# size of array 1000
# index 260
# size of array 1000
# index 260
# Hashed index 230
# size of array 1000
# index 230
# size of array 1000
# index 230
# Hashed index 839
# size of array 1000
# index 839
# size of array 1000
# index 839
# Hashed index 348
# size of array 1000
# index 348
# size of array 1000
# index 348
# Hashed index 872
# size of array 1000
# index 872
# size of array 1000
# index 872
# Hashed index 206
# size of array 1000
# index 206
# size of array 1000
# index 206
# Hashed index 11
# size of array 1000
# index 11
# size of array 1000
# index 11
# Hashed index 781
# size of array 1000
# index 781
# size of array 1000
# index 781
# Hashed index 618
# size of array 1000
# index 618
# size of array 1000
# index 618
# Hashed index 928
# size of array 1000
# index 928
# size of array 1000
# index 928
# Hashed index 37
# size of array 1000
# index 37
# size of array 1000
# index 37
# Hashed index 690
# size of array 1000
# index 690
# size of array 1000
# index 690
# Hashed index 638
# size of array 1000
# index 638
# size of array 1000
# index 638
# Hashed index 731
# size of array 1000
# index 731
# size of array 1000
# index 731
# Hashed index 735
# size of array 1000
# index 735
# size of array 1000
# index 735
# Hashed index 716
# size of array 1000
# index 716
# size of array 1000
# index 716
# Hashed index 282
# size of array 1000
# index 282
# size of array 1000
# index 282
# Hashed index 319
# size of array 1000
# index 319
# size of array 1000
# index 319
# Hashed index 670
# size of array 1000
# index 670
# size of array 1000
# index 670
# Hashed index 775
# size of array 1000
# index 775
# size of array 1000
# index 775
# Hashed index 906
# size of array 1000
# index 906
# size of array 1000
# index 906
# Hashed index 396
# size of array 1000
# index 396
# size of array 1000
# index 396
# Hashed index 812
# size of array 1000
# index 812
# size of array 1000
# index 812
# Hashed index 864
# size of array 1000
# index 864
# size of array 1000
# index 864
# Hashed index 676
# size of array 1000
# index 676
# size of array 1000
# index 676
# Hashed index 355
# size of array 1000
# index 355
# size of array 1000
# index 355
# Hashed index 16
# size of array 1000
# index 16
# size of array 1000
# index 16
# Hashed index 891
# size of array 1000
# index 891
# size of array 1000
# index 891
# Hashed index 770
# size of array 1000
# index 770
# size of array 1000
# index 770
# Hashed index 509
# size of array 1000
# index 509
# size of array 1000
# index 509
# Hashed index 918
# size of array 1000
# index 918
# size of array 1000
# index 918
# Hashed index 428
# size of array 1000
# index 428
# size of array 1000
# index 428
# Hashed index 855
# size of array 1000
# index 855
# size of array 1000
# index 855
# Hashed index 150
# size of array 1000
# index 150
# size of array 1000
# index 150
# Hashed index 999
# size of array 1000
# index 999
# size of array 1000
# index 999
# Hashed index 476
# size of array 1000
# index 476
# size of array 1000
# index 476
# Hashed index 839
# size of array 1000
# index 839
# size of array 1000
# index 839
# Hashed index 585
# size of array 1000
# index 585
# size of array 1000
# index 585
# Hashed index 630
# size of array 1000
# index 630
# size of array 1000
# index 630
# Hashed index 450
# size of array 1000
# index 450
# size of array 1000
# index 450
# Hashed index 9
# size of array 1000
# index 9
# size of array 1000
# index 9
# Hashed index 772
# size of array 1000
# index 772
# size of array 1000
# index 772
# Hashed index 907
# size of array 1000
# index 907
# size of array 1000
# index 907
# Hashed index 675
# size of array 1000
# index 675
# size of array 1000
# index 675
# Hashed index 327
# size of array 1000
# index 327
# size of array 1000
# index 327
# Hashed index 977
# size of array 1000
# index 977
# size of array 1000
# index 977
# Hashed index 737
# size of array 1000
# index 737
# size of array 1000
# index 737
# Hashed index 297
# size of array 1000
# index 297
# size of array 1000
# index 297
# Hashed index 735
# size of array 1000
# index 735
# size of array 1000
# index 735
# Hashed index 441
# size of array 1000
# index 441
# size of array 1000
# index 441
# Hashed index 358
# size of array 1000
# index 358
# size of array 1000
# index 358
# Hashed index 335
# size of array 1000
# index 335
# size of array 1000
# index 335
# Hashed index 664
# size of array 1000
# index 664
# size of array 1000
# index 664
# Hashed index 749
# size of array 1000
# index 749
# size of array 1000
# index 749
# Hashed index 49
# size of array 1000
# index 49
# size of array 1000
# index 49
# Hashed index 538
# size of array 1000
# index 538
# size of array 1000
# index 538
# Hashed index 628
# size of array 1000
# index 628
# size of array 1000
# index 628
# Hashed index 429
# size of array 1000
# index 429
# size of array 1000
# index 429
# Hashed index 561
# size of array 1000
# index 561
# size of array 1000
# index 561
# Hashed index 138
# size of array 1000
# index 138
# size of array 1000
# index 138
# Hashed index 881
# size of array 1000
# index 881
# size of array 1000
# index 881
# Hashed index 760
# size of array 1000
# index 760
# size of array 1000
# index 760
# Hashed index 92
# size of array 1000
# index 92
# size of array 1000
# index 92
# Hashed index 957
# size of array 1000
# index 957
# size of array 1000
# index 957
# Hashed index 276
# size of array 1000
# index 276
# size of array 1000
# index 276
# Hashed index 17
# size of array 1000
# index 17
# size of array 1000
# index 17
# Hashed index 743
# size of array 1000
# index 743
# size of array 1000
# index 743
# Hashed index 852
# size of array 1000
# index 852
# size of array 1000
# index 852
# Hashed index 337
# size of array 1000
# index 337
# size of array 1000
# index 337
# Hashed index 794
# size of array 1000
# index 794
# size of array 1000
# index 794
# Hashed index 244
# size of array 1000
# index 244
# size of array 1000
# index 244
# Hashed index 481
# size of array 1000
# index 481
# size of array 1000
# index 481
# Hashed index 161
# size of array 1000
# index 161
# size of array 1000
# index 161
# Hashed index 970
# size of array 1000
# index 970
# size of array 1000
# index 970
# Hashed index 257
# size of array 1000
# index 257
# size of array 1000
# index 257
# Hashed index 689
# size of array 1000
# index 689
# size of array 1000
# index 689
# Hashed index 97
# size of array 1000
# index 97
# size of array 1000
# index 97
# Hashed index 340
# size of array 1000
# index 340
# size of array 1000
# index 340
# Hashed index 381
# size of array 1000
# index 381
# size of array 1000
# index 381
# Hashed index 153
# size of array 1000
# index 153
# size of array 1000
# index 153
# Hashed index 607
# size of array 1000
# index 607
# size of array 1000
# index 607
# Hashed index 609
# size of array 1000
# index 609
# size of array 1000
# index 609
# Hashed index 53
# size of array 1000
# index 53
# size of array 1000
# index 53
# Hashed index 660
# size of array 1000
# index 660
# size of array 1000
# index 660
# Hashed index 970
# size of array 1000
# index 970
# size of array 1000
# index 970
# Hashed index 846
# size of array 1000
# index 846
# size of array 1000
# index 846
# Hashed index 89
# size of array 1000
# index 89
# size of array 1000
# index 89
# Hashed index 207
# size of array 1000
# index 207
# size of array 1000
# index 207
# Hashed index 668
# size of array 1000
# index 668
# size of array 1000
# index 668
# Hashed index 732
# size of array 1000
# index 732
# size of array 1000
# index 732
# Hashed index 743
# size of array 1000
# index 743
# size of array 1000
# index 743
# Hashed index 907
# size of array 1000
# index 907
# size of array 1000
# index 907
# Hashed index 451
# size of array 1000
# index 451
# size of array 1000
# index 451
# Hashed index 617
# size of array 1000
# index 617
# size of array 1000
# index 617
# Hashed index 253
# size of array 1000
# index 253
# size of array 1000
# index 253
# Hashed index 769
# size of array 1000
# index 769
# size of array 1000
# index 769
# Hashed index 556
# size of array 1000
# index 556
# size of array 1000
# index 556
# Hashed index 222
# size of array 1000
# index 222
# size of array 1000
# index 222
# Hashed index 614
# size of array 1000
# index 614
# size of array 1000
# index 614
# Hashed index 519
# size of array 1000
# index 519
# size of array 1000
# index 519
# Hashed index 245
# size of array 1000
# index 245
# size of array 1000
# index 245
# Hashed index 930
# size of array 1000
# index 930
# size of array 1000
# index 930
# Hashed index 610
# size of array 1000
# index 610
# size of array 1000
# index 610
# Hashed index 138
# size of array 1000
# index 138
# size of array 1000
# index 138
# Hashed index 763
# size of array 1000
# index 763
# size of array 1000
# index 763
# Hashed index 884
# size of array 1000
# index 884
# size of array 1000
# index 884
# Hashed index 916
# size of array 1000
# index 916
# size of array 1000
# index 916
# Hashed index 388
# size of array 1000
# index 388
# size of array 1000
# index 388
# Hashed index 492
# size of array 1000
# index 492
# size of array 1000
# index 492
# Hashed index 628
# size of array 1000
# index 628
# size of array 1000
# index 628
# Hashed index 323
# size of array 1000
# index 323
# size of array 1000
# index 323
# Hashed index 744
# size of array 1000
# index 744
# size of array 1000
# index 744
# Hashed index 457
# size of array 1000
# index 457
# size of array 1000
# index 457
# Hashed index 83
# size of array 1000
# index 83
# size of array 1000
# index 83
# Hashed index 122
# size of array 1000
# index 122
# size of array 1000
# index 122
# Hashed index 502
# size of array 1000
# index 502
# size of array 1000
# index 502
# Hashed index 112
# size of array 1000
# index 112
# size of array 1000
# index 112
# Hashed index 548
# size of array 1000
# index 548
# size of array 1000
# index 548
# Hashed index 537
# size of array 1000
# index 537
# size of array 1000
# index 537
# Hashed index 253
# size of array 1000
# index 253
# size of array 1000
# index 253
# Hashed index 376
# size of array 1000
# index 376
# size of array 1000
# index 376
# Hashed index 310
# size of array 1000
# index 310
# size of array 1000
# index 310
# Hashed index 66
# size of array 1000
# index 66
# size of array 1000
# index 66
# Hashed index 28
# size of array 1000
# index 28
# size of array 1000
# index 28
# Hashed index 653
# size of array 1000
# index 653
# size of array 1000
# index 653
# Hashed index 91
# size of array 1000
# index 91
# size of array 1000
# index 91
# Hashed index 891
# size of array 1000
# index 891
# size of array 1000
# index 891
# Hashed index 538
# size of array 1000
# index 538
# size of array 1000
# index 538
# Hashed index 342
# size of array 1000
# index 342
# size of array 1000
# index 342
# Hashed index 5
# size of array 1000
# index 5
# size of array 1000
# index 5
# Hashed index 653
# size of array 1000
# index 653
# size of array 1000
# index 653
# Hashed index 883
# size of array 1000
# index 883
# size of array 1000
# index 883
# Hashed index 353
# size of array 1000
# index 353
# size of array 1000
# index 353
# Hashed index 497
# size of array 1000
# index 497
# size of array 1000
# index 497
# Hashed index 830
# size of array 1000
# index 830
# size of array 1000
# index 830
# Hashed index 122
# size of array 1000
# index 122
# size of array 1000
# index 122
# Hashed index 224
# size of array 1000
# index 224
# size of array 1000
# index 224
# Hashed index 656
# size of array 1000
# index 656
# size of array 1000
# index 656
# Hashed index 993
# size of array 1000
# index 993
# size of array 1000
# index 993
# Hashed index 24
# size of array 1000
# index 24
# size of array 1000
# index 24
# Hashed index 707
# size of array 1000
# index 707
# size of array 1000
# index 707
# Hashed index 618
# size of array 1000
# index 618
# size of array 1000
# index 618
# Hashed index 747
# size of array 1000
# index 747
# size of array 1000
# index 747
# Hashed index 600
# size of array 1000
# index 600
# size of array 1000
# index 600
# Hashed index 603
# size of array 1000
# index 603
# size of array 1000
# index 603
# Hashed index 357
# size of array 1000
# index 357
# size of array 1000
# index 357
# Hashed index 935
# size of array 1000
# index 935
# size of array 1000
# index 935
# Hashed index 821
# size of array 1000
# index 821
# size of array 1000
# index 821
# Hashed index 394
# size of array 1000
# index 394
# size of array 1000
# index 394
# Hashed index 174
# size of array 1000
# index 174
# size of array 1000
# index 174
# Hashed index 90
# size of array 1000
# index 90
# size of array 1000
# index 90
# Hashed index 523
# size of array 1000
# index 523
# size of array 1000
# index 523
# Hashed index 484
# size of array 1000
# index 484
# size of array 1000
# index 484
# Hashed index 997
# size of array 1000
# index 997
# size of array 1000
# index 997
# Hashed index 336
# size of array 1000
# index 336
# size of array 1000
# index 336
# Hashed index 635
# size of array 1000
# index 635
# size of array 1000
# index 635
# Hashed index 226
# size of array 1000
# index 226
# size of array 1000
# index 226
# Hashed index 720
# size of array 1000
# index 720
# size of array 1000
# index 720
# Hashed index 441
# size of array 1000
# index 441
# size of array 1000
# index 441
# Hashed index 626
# size of array 1000
# index 626
# size of array 1000
# index 626
# Hashed index 141
# size of array 1000
# index 141
# size of array 1000
# index 141
# Hashed index 123
# size of array 1000
# index 123
# size of array 1000
# index 123
# Hashed index 843
# size of array 1000
# index 843
# size of array 1000
# index 843
# Hashed index 482
# size of array 1000
# index 482
# size of array 1000
# index 482
# Hashed index 760
# size of array 1000
# index 760
# size of array 1000
# index 760
# Hashed index 343
# size of array 1000
# index 343
# size of array 1000
# index 343
# Hashed index 95
# size of array 1000
# index 95
# size of array 1000
# index 95
# Hashed index 672
# size of array 1000
# index 672
# size of array 1000
# index 672
# Hashed index 436
# size of array 1000
# index 436
# size of array 1000
# index 436
# Hashed index 111
# size of array 1000
# index 111
# size of array 1000
# index 111
# Hashed index 844
# size of array 1000
# index 844
# size of array 1000
# index 844
# Hashed index 675
# size of array 1000
# index 675
# size of array 1000
# index 675
# Hashed index 654
# size of array 1000
# index 654
# size of array 1000
# index 654
# Hashed index 277
# size of array 1000
# index 277
# size of array 1000
# index 277
# Hashed index 655
# size of array 1000
# index 655
# size of array 1000
# index 655
# Hashed index 380
# size of array 1000
# index 380
# size of array 1000
# index 380
# Hashed index 838
# size of array 1000
# index 838
# size of array 1000
# index 838
# Hashed index 694
# size of array 1000
# index 694
# size of array 1000
# index 694
# Hashed index 398
# size of array 1000
# index 398
# size of array 1000
# index 398
# Hashed index 443
# size of array 1000
# index 443
# size of array 1000
# index 443
# Hashed index 276
# size of array 1000
# index 276
# size of array 1000
# index 276
# Hashed index 932
# size of array 1000
# index 932
# size of array 1000
# index 932
# Hashed index 832
# size of array 1000
# index 832
# size of array 1000
# index 832
# Hashed index 588
# size of array 1000
# index 588
# size of array 1000
# index 588
# Hashed index 355
# size of array 1000
# index 355
# size of array 1000
# index 355
# Hashed index 118
# size of array 1000
# index 118
# size of array 1000
# index 118
# Hashed index 943
# size of array 1000
# index 943
# size of array 1000
# index 943
# Hashed index 167
# size of array 1000
# index 167
# size of array 1000
# index 167
# Hashed index 895
# size of array 1000
# index 895
# size of array 1000
# index 895
# Hashed index 68
# size of array 1000
# index 68
# size of array 1000
# index 68
# Hashed index 415
# size of array 1000
# index 415
# size of array 1000
# index 415
# Hashed index 473
# size of array 1000
# index 473
# size of array 1000
# index 473
# Hashed index 617
# size of array 1000
# index 617
# size of array 1000
# index 617
# Hashed index 591
# size of array 1000
# index 591
# size of array 1000
# index 591
# Hashed index 966
# size of array 1000
# index 966
# size of array 1000
# index 966
# Hashed index 668
# size of array 1000
# index 668
# size of array 1000
# index 668
# Hashed index 46
# size of array 1000
# index 46
# size of array 1000
# index 46
# Hashed index 735
# size of array 1000
# index 735
# size of array 1000
# index 735
# Hashed index 690
# size of array 1000
# index 690
# size of array 1000
# index 690
# Hashed index 466
# size of array 1000
# index 466
# size of array 1000
# index 466
# Hashed index 419
# size of array 1000
# index 419
# size of array 1000
# index 419
# Hashed index 828
# size of array 1000
# index 828
# size of array 1000
# index 828
# Hashed index 195
# size of array 1000
# index 195
# size of array 1000
# index 195
# Hashed index 78
# size of array 1000
# index 78
# size of array 1000
# index 78
# Hashed index 300
# size of array 1000
# index 300
# size of array 1000
# index 300
# Hashed index 293
# size of array 1000
# index 293
# size of array 1000
# index 293
# Hashed index 858
# size of array 1000
# index 858
# size of array 1000
# index 858
# Hashed index 237
# size of array 1000
# index 237
# size of array 1000
# index 237
# Hashed index 171
# size of array 1000
# index 171
# size of array 1000
# index 171
# Hashed index 564
# size of array 1000
# index 564
# size of array 1000
# index 564
# Hashed index 840
# size of array 1000
# index 840
# size of array 1000
# index 840
# Hashed index 136
# size of array 1000
# index 136
# size of array 1000
# index 136
# Hashed index 389
# size of array 1000
# index 389
# size of array 1000
# index 389
# Hashed index 60
# size of array 1000
# index 60
# size of array 1000
# index 60
# Hashed index 975
# size of array 1000
# index 975
# size of array 1000
# index 975
# Hashed index 693
# size of array 1000
# index 693
# size of array 1000
# index 693
# Hashed index 398
# size of array 1000
# index 398
# size of array 1000
# index 398
# Hashed index 529
# size of array 1000
# index 529
# size of array 1000
# index 529
# Hashed index 291
# size of array 1000
# index 291
# size of array 1000
# index 291
# Hashed index 856
# size of array 1000
# index 856
# size of array 1000
# index 856
# Hashed index 350
# size of array 1000
# index 350
# size of array 1000
# index 350
# Hashed index 763
# size of array 1000
# index 763
# size of array 1000
# index 763
# Hashed index 402
# size of array 1000
# index 402
# size of array 1000
# index 402
# Hashed index 42
# size of array 1000
# index 42
# size of array 1000
# index 42
# Hashed index 380
# size of array 1000
# index 380
# size of array 1000
# index 380
# Hashed index 15
# size of array 1000
# index 15
# size of array 1000
# index 15
# Hashed index 681
# size of array 1000
# index 681
# size of array 1000
# index 681
# Hashed index 397
# size of array 1000
# index 397
# size of array 1000
# index 397
# Hashed index 45
# size of array 1000
# index 45
# size of array 1000
# index 45
# Hashed index 103
# size of array 1000
# index 103
# size of array 1000
# index 103
# Hashed index 286
# size of array 1000
# index 286
# size of array 1000
# index 286
# Hashed index 865
# size of array 1000
# index 865
# size of array 1000
# index 865
# Hashed index 811
# size of array 1000
# index 811
# size of array 1000
# index 811
# Hashed index 44
# size of array 1000
# index 44
# size of array 1000
# index 44
# Hashed index 514
# size of array 1000
# index 514
# size of array 1000
# index 514
# Hashed index 453
# size of array 1000
# index 453
# size of array 1000
# index 453
# Hashed index 59
# size of array 1000
# index 59
# size of array 1000
# index 59
# Hashed index 257
# size of array 1000
# index 257
# size of array 1000
# index 257
# Hashed index 386
# size of array 1000
# index 386
# size of array 1000
# index 386
# Hashed index 405
# size of array 1000
# index 405
# size of array 1000
# index 405
# Hashed index 260
# size of array 1000
# index 260
# size of array 1000
# index 260
# Hashed index 68
# size of array 1000
# index 68
# size of array 1000
# index 68
# Hashed index 363
# size of array 1000
# index 363
# size of array 1000
# index 363
# Hashed index 208
# size of array 1000
# index 208
# size of array 1000
# index 208
# Hashed index 324
# size of array 1000
# index 324
# size of array 1000
# index 324
# Hashed index 362
# size of array 1000
# index 362
# size of array 1000
# index 362
# Hashed index 925
# size of array 1000
# index 925
# size of array 1000
# index 925
# Hashed index 975
# size of array 1000
# index 975
# size of array 1000
# index 975
# Hashed index 137
# size of array 1000
# index 137
# size of array 1000
# index 137
# Hashed index 546
# size of array 1000
# index 546
# size of array 1000
# index 546
# Hashed index 99
# size of array 1000
# index 99
# size of array 1000
# index 99
# Hashed index 924
# size of array 1000
# index 924
# size of array 1000
# index 924
# Hashed index 400
# size of array 1000
# index 400
# size of array 1000
# index 400
# Hashed index 25
# size of array 1000
# index 25
# size of array 1000
# index 25
# Hashed index 982
# size of array 1000
# index 982
# size of array 1000
# index 982
# Hashed index 697
# size of array 1000
# index 697
# size of array 1000
# index 697
# Hashed index 200
# size of array 1000
# index 200
# size of array 1000
# index 200
# Hashed index 704
# size of array 1000
# index 704
# size of array 1000
# index 704
# Hashed index 677
# size of array 1000
# index 677
# size of array 1000
# index 677
# Hashed index 711
# size of array 1000
# index 711
# size of array 1000
# index 711
# Hashed index 850
# size of array 1000
# index 850
# size of array 1000
# index 850
# Hashed index 837
# size of array 1000
# index 837
# size of array 1000
# index 837
# Hashed index 6
# size of array 1000
# index 6
# size of array 1000
# index 6
# Hashed index 30
# size of array 1000
# index 30
# size of array 1000
# index 30
# Hashed index 954
# size of array 1000
# index 954
# size of array 1000
# index 954
# Hashed index 44
# size of array 1000
# index 44
# size of array 1000
# index 44
# Hashed index 561
# size of array 1000
# index 561
# size of array 1000
# index 561
# Hashed index 63
# size of array 1000
# index 63
# size of array 1000
# index 63
# Hashed index 587
# size of array 1000
# index 587
# size of array 1000
# index 587
# Hashed index 451
# size of array 1000
# index 451
# size of array 1000
# index 451
# Hashed index 366
# size of array 1000
# index 366
# size of array 1000
# index 366
# Hashed index 92
# size of array 1000
# index 92
# size of array 1000
# index 92
# Hashed index 427
# size of array 1000
# index 427
# size of array 1000
# index 427
# Hashed index 536
# size of array 1000
# index 536
# size of array 1000
# index 536
# Hashed index 409
# size of array 1000
# index 409
# size of array 1000
# index 409
# Hashed index 908
# size of array 1000
# index 908
# size of array 1000
# index 908
# Hashed index 962
# size of array 1000
# index 962
# size of array 1000
# index 962
# Hashed index 352
# size of array 1000
# index 352
# size of array 1000
# index 352
# Hashed index 775
# size of array 1000
# index 775
# size of array 1000
# index 775
# Hashed index 381
# size of array 1000
# index 381
# size of array 1000
# index 381
# Hashed index 778
# size of array 1000
# index 778
# size of array 1000
# index 778
# Hashed index 778
# size of array 1000
# index 778
# size of array 1000
# index 778
# Hashed index 676
# size of array 1000
# index 676
# size of array 1000
# index 676
# Hashed index 491
# size of array 1000
# index 491
# size of array 1000
# index 491
# Hashed index 645
# size of array 1000
# index 645
# size of array 1000
# index 645
# Hashed index 784
# size of array 1000
# index 784
# size of array 1000
# index 784
# Hashed index 424
# size of array 1000
# index 424
# size of array 1000
# index 424
# Hashed index 516
# size of array 1000
# index 516
# size of array 1000
# index 516
# Hashed index 60
# size of array 1000
# index 60
# size of array 1000
# index 60
# Hashed index 88
# size of array 1000
# index 88
# size of array 1000
# index 88
# Hashed index 165
# size of array 1000
# index 165
# size of array 1000
# index 165
# Hashed index 928
# size of array 1000
# index 928
# size of array 1000
# index 928
# Hashed index 553
# size of array 1000
# index 553
# size of array 1000
# index 553
# Hashed index 466
# size of array 1000
# index 466
# size of array 1000
# index 466
# Hashed index 795
# size of array 1000
# index 795
# size of array 1000
# index 795
# Hashed index 82
# size of array 1000
# index 82
# size of array 1000
# index 82
# Hashed index 25
# size of array 1000
# index 25
# size of array 1000
# index 25
# Hashed index 584
# size of array 1000
# index 584
# size of array 1000
# index 584
# Hashed index 512
# size of array 1000
# index 512
# size of array 1000
# index 512
# Hashed index 5
# size of array 1000
# index 5
# size of array 1000
# index 5
# Hashed index 646
# size of array 1000
# index 646
# size of array 1000
# index 646
# Hashed index 302
# size of array 1000
# index 302
# size of array 1000
# index 302
# Hashed index 300
# size of array 1000
# index 300
# size of array 1000
# index 300
# Hashed index 297
# size of array 1000
# index 297
# size of array 1000
# index 297
# Hashed index 38
# size of array 1000
# index 38
# size of array 1000
# index 38
# Hashed index 418
# size of array 1000
# index 418
# size of array 1000
# index 418
# Hashed index 924
# size of array 1000
# index 924
# size of array 1000
# index 924
# Hashed index 293
# size of array 1000
# index 293
# size of array 1000
# index 293
# Hashed index 279
# size of array 1000
# index 279
# size of array 1000
# index 279
# Hashed index 224
# size of array 1000
# index 224
# size of array 1000
# index 224
# Hashed index 25
# size of array 1000
# index 25
# size of array 1000
# index 25
# Hashed index 963
# size of array 1000
# index 963
# size of array 1000
# index 963
# Hashed index 638
# size of array 1000
# index 638
# size of array 1000
# index 638
# Hashed index 179
# size of array 1000
# index 179
# size of array 1000
# index 179
# Hashed index 212
# size of array 1000
# index 212
# size of array 1000
# index 212
# Hashed index 207
# size of array 1000
# index 207
# size of array 1000
# index 207
# Hashed index 115
# size of array 1000
# index 115
# size of array 1000
# index 115
# Hashed index 367
# size of array 1000
# index 367
# size of array 1000
# index 367
# Hashed index 721
# size of array 1000
# index 721
# size of array 1000
# index 721
# Hashed index 417
# size of array 1000
# index 417
# size of array 1000
# index 417
# Hashed index 786
# size of array 1000
# index 786
# size of array 1000
# index 786
# Hashed index 242
# size of array 1000
# index 242
# size of array 1000
# index 242
# Hashed index 745
# size of array 1000
# index 745
# size of array 1000
# index 745
# Hashed index 433
# size of array 1000
# index 433
# size of array 1000
# index 433
# Hashed index 661
# size of array 1000
# index 661
# size of array 1000
# index 661
# Hashed index 431
# size of array 1000
# index 431
# size of array 1000
# index 431
# Hashed index 668
# size of array 1000
# index 668
# size of array 1000
# index 668
# Hashed index 514
# size of array 1000
# index 514
# size of array 1000
# index 514
# Hashed index 782
# size of array 1000
# index 782
# size of array 1000
# index 782
# Hashed index 448
# size of array 1000
# index 448
# size of array 1000
# index 448
# Hashed index 613
# size of array 1000
# index 613
# size of array 1000
# index 613
# Hashed index 61
# size of array 1000
# index 61
# size of array 1000
# index 61
# Hashed index 379
# size of array 1000
# index 379
# size of array 1000
# index 379
# Hashed index 892
# size of array 1000
# index 892
# size of array 1000
# index 892
# Hashed index 949
# size of array 1000
# index 949
# size of array 1000
# index 949
# Hashed index 609
# size of array 1000
# index 609
# size of array 1000
# index 609
# Hashed index 320
# size of array 1000
# index 320
# size of array 1000
# index 320
# Hashed index 187
# size of array 1000
# index 187
# size of array 1000
# index 187
# Hashed index 711
# size of array 1000
# index 711
# size of array 1000
# index 711
# Hashed index 845
# size of array 1000
# index 845
# size of array 1000
# index 845
# Hashed index 520
# size of array 1000
# index 520
# size of array 1000
# index 520
# Hashed index 693
# size of array 1000
# index 693
# size of array 1000
# index 693
# Hashed index 542
# size of array 1000
# index 542
# size of array 1000
# index 542
# Hashed index 10
# size of array 1000
# index 10
# size of array 1000
# index 10
# Hashed index 254
# size of array 1000
# index 254
# size of array 1000
# index 254
# Hashed index 435
# size of array 1000
# index 435
# size of array 1000
# index 435
# Hashed index 465
# size of array 1000
# index 465
# size of array 1000
# index 465
# Hashed index 258
# size of array 1000
# index 258
# size of array 1000
# index 258
# Hashed index 162
# size of array 1000
# index 162
# size of array 1000
# index 162
# Hashed index 75
# size of array 1000
# index 75
# size of array 1000
# index 75
# Hashed index 432
# size of array 1000
# index 432
# size of array 1000
# index 432
# Hashed index 232
# size of array 1000
# index 232
# size of array 1000
# index 232
# Hashed index 419
# size of array 1000
# index 419
# size of array 1000
# index 419
# Hashed index 148
# size of array 1000
# index 148
# size of array 1000
# index 148
# Hashed index 183
# size of array 1000
# index 183
# size of array 1000
# index 183
# Hashed index 867
# size of array 1000
# index 867
# size of array 1000
# index 867
# Hashed index 47
# size of array 1000
# index 47
# size of array 1000
# index 47
# Hashed index 497
# size of array 1000
# index 497
# size of array 1000
# index 497
# Hashed index 763
# size of array 1000
# index 763
# size of array 1000
# index 763
# Hashed index 191
# size of array 1000
# index 191
# size of array 1000
# index 191
# Hashed index 426
# size of array 1000
# index 426
# size of array 1000
# index 426
# Hashed index 521
# size of array 1000
# index 521
# size of array 1000
# index 521
# Hashed index 941
# size of array 1000
# index 941
# size of array 1000
# index 941
# Hashed index 677
# size of array 1000
# index 677
# size of array 1000
# index 677
# Hashed index 258
# size of array 1000
# index 258
# size of array 1000
# index 258
# Hashed index 294
# size of array 1000
# index 294
# size of array 1000
# index 294
# Hashed index 652
# size of array 1000
# index 652
# size of array 1000
# index 652
# Hashed index 494
# size of array 1000
# index 494
# size of array 1000
# index 494
# Hashed index 330
# size of array 1000
# index 330
# size of array 1000
# index 330
# Hashed index 688
# size of array 1000
# index 688
# size of array 1000
# index 688
# Hashed index 540
# size of array 1000
# index 540
# size of array 1000
# index 540
# Hashed index 843
# size of array 1000
# index 843
# size of array 1000
# index 843
# Hashed index 790
# size of array 1000
# index 790
# size of array 1000
# index 790
# Hashed index 610
# size of array 1000
# index 610
# size of array 1000
# index 610
# Hashed index 473
# size of array 1000
# index 473
# size of array 1000
# index 473
# Hashed index 460
# size of array 1000
# index 460
# size of array 1000
# index 460
# Hashed index 489
# size of array 1000
# index 489
# size of array 1000
# index 489
# Hashed index 64
# size of array 1000
# index 64
# size of array 1000
# index 64
# Hashed index 185
# size of array 1000
# index 185
# size of array 1000
# index 185
# Hashed index 758
# size of array 1000
# index 758
# size of array 1000
# index 758
# Hashed index 185
# size of array 1000
# index 185
# size of array 1000
# index 185
# Hashed index 154
# size of array 1000
# index 154
# size of array 1000
# index 154
# Hashed index 864
# size of array 1000
# index 864
# size of array 1000
# index 864
# Hashed index 451
# size of array 1000
# index 451
# size of array 1000
# index 451
# Hashed index 214
# size of array 1000
# index 214
# size of array 1000
# index 214
# Hashed index 475
# size of array 1000
# index 475
# size of array 1000
# ...
# index 852
# Hashed index 637
# size of array 1000
# index 637
# size of array 1000
# index 637
# Hashed index 387
# size of array 1000
# index 387
# size of array 1000
# index 387
# Hashed index 419
# size of array 1000
# index 419
# size of array 1000
# index 419
# Hashed index 341
# size of array 1000
# index 341
# size of array 1000
# index 341
# Hashed index 640
# size of array 1000
# index 640
# size of array 1000
# index 640
# Hashed index 938
# size of array 1000
# index 938
# size of array 1000
# index 938
# Hashed index 649
# size of array 1000
# index 649
# size of array 1000
# index 649
# Hashed index 104
# size of array 1000
# index 104
# size of array 1000
# index 104
# Hashed index 230
# size of array 1000
# index 230
# size of array 1000
# index 230
# Hashed index 681
# size of array 1000
# index 681
# size of array 1000
# index 681
# Hashed index 415
# size of array 1000
# index 415
# size of array 1000
# index 415
# Hashed index 384
# size of array 1000
# index 384
# size of array 1000
# index 384
# Hashed index 450
# size of array 1000
# index 450
# size of array 1000
# index 450
# Hashed index 160
# size of array 1000
# index 160
# size of array 1000
# index 160
# Hashed index 1
# size of array 1000
# index 1
# size of array 1000
# index 1
# Hashed index 46
# size of array 1000
# index 46
# size of array 1000
# index 46
# Hashed index 465
# size of array 1000
# index 465
# size of array 1000
# index 465
# Hashed index 256
# size of array 1000
# index 256
# size of array 1000
# index 256
# Hashed index 702
# size of array 1000
# index 702
# size of array 1000
# index 702
# Hashed index 294
# size of array 1000
# index 294
# size of array 1000
# index 294
# Hashed index 295
# size of array 1000
# index 295
# size of array 1000
# index 295
# Hashed index 828
# size of array 1000
# index 828
# size of array 1000
# index 828
# Hashed index 128
# size of array 1000
# index 128
# size of array 1000
# index 128
# Hashed index 908
# size of array 1000
# index 908
# size of array 1000
# index 908
# Hashed index 945
# size of array 1000
# index 945
# size of array 1000
# index 945
# Hashed index 97
# size of array 1000
# index 97
# size of array 1000
# index 97
# Hashed index 365
# size of array 1000
# index 365
# size of array 1000
# index 365
# Hashed index 610
# size of array 1000
# index 610
# size of array 1000
# index 610
# Hashed index 202
# size of array 1000
# index 202
# size of array 1000
# index 202
# Hashed index 599
# size of array 1000
# index 599
# size of array 1000
# index 599
# Hashed index 330
# size of array 1000
# index 330
# size of array 1000
# index 330
# Hashed index 899
# size of array 1000
# index 899
# size of array 1000
# index 899
# Hashed index 797
# size of array 1000
# index 797
# size of array 1000
# index 797
# Hashed index 397
# size of array 1000
# index 397
# size of array 1000
# index 397
# Hashed index 249
# size of array 1000
# index 249
# size of array 1000
# index 249
# Hashed index 837
# size of array 1000
# index 837
# size of array 1000
# index 837
# Hashed index 63
# size of array 1000
# index 63
# size of array 1000
# index 63
# Hashed index 621
# size of array 1000
# index 621
# size of array 1000
# index 621
# Hashed index 783
# size of array 1000
# index 783
# size of array 1000
# index 783
# Hashed index 227
# size of array 1000
# index 227
# size of array 1000
# index 227
# Hashed index 273
# size of array 1000
# index 273
# size of array 1000
# index 273
# Hashed index 9
# size of array 1000
# index 9
# size of array 1000
# index 9
# Hashed index 727
# size of array 1000
# index 727
# size of array 1000
# index 727
# Hashed index 215
# size of array 1000
# index 215
# size of array 1000
# index 215
# Hashed index 91
# size of array 1000
# index 91
# size of array 1000
# index 91
# Hashed index 572
# size of array 1000
# index 572
# size of array 1000
# index 572
# Hashed index 267
# size of array 1000
# index 267
# size of array 1000
# index 267
# Hashed index 252
# size of array 1000
# index 252
# size of array 1000
# index 252
# Hashed index 443
# size of array 1000
# index 443
# size of array 1000
# index 443
# Hashed index 947
# size of array 1000
# index 947
# size of array 1000
# index 947
# Hashed index 377
# size of array 1000
# index 377
# size of array 1000
# index 377
# Hashed index 633
# size of array 1000
# index 633
# size of array 1000
# index 633
# Hashed index 822
# size of array 1000
# index 822
# size of array 1000
# index 822
# Hashed index 756
# size of array 1000
# index 756
# size of array 1000
# index 756
# Hashed index 625
# size of array 1000
# index 625
# size of array 1000
# index 625
# Hashed index 368
# size of array 1000
# index 368
# size of array 1000
# index 368
# Hashed index 737
# size of array 1000
# index 737
# size of array 1000
# index 737
# Hashed index 212
# size of array 1000
# index 212
# size of array 1000
# index 212
# Hashed index 751
# size of array 1000
# index 751
# size of array 1000
# index 751
# Hashed index 984
# size of array 1000
# index 984
# size of array 1000
# index 984
# Hashed index 30
# size of array 1000
# index 30
# size of array 1000
# index 30
# Hashed index 9
# size of array 1000
# index 9
# size of array 1000
# index 9
# Hashed index 393
# size of array 1000
# index 393
# size of array 1000
# index 393
# Hashed index 280
# size of array 1000
# index 280
# size of array 1000
# index 280
# Hashed index 503
# size of array 1000
# index 503
# size of array 1000
# index 503
# Hashed index 815
# size of array 1000
# index 815
# size of array 1000
# index 815
# Hashed index 508
# size of array 1000
# index 508
# size of array 1000
# index 508
# Hashed index 369
# size of array 1000
# index 369
# size of array 1000
# index 369
# Hashed index 581
# size of array 1000
# index 581
# size of array 1000
# index 581
# Hashed index 159
# size of array 1000
# index 159
# size of array 1000
# index 159
# Hashed index 228
# size of array 1000
# index 228
# size of array 1000
# index 228
# Hashed index 63
# size of array 1000
# index 63
# size of array 1000
# index 63
# Hashed index 77
# size of array 1000
# index 77
# size of array 1000
# index 77
# Hashed index 183
# size of array 1000
# index 183
# size of array 1000
# index 183
# Hashed index 950
# size of array 1000
# index 950
# size of array 1000
# index 950
# Hashed index 223
# size of array 1000
# index 223
# size of array 1000
# index 223
# Hashed index 98
# size of array 1000
# index 98
# size of array 1000
# index 98
# Hashed index 870
# size of array 1000
# index 870
# size of array 1000
# index 870
# Hashed index 66
# size of array 1000
# index 66
# size of array 1000
# index 66
# Hashed index 78
# size of array 1000
# index 78
# size of array 1000
# index 78
# Hashed index 535
# size of array 1000
# index 535
# size of array 1000
# index 535
# Hashed index 121
# size of array 1000
# index 121
# size of array 1000
# index 121
# Hashed index 893
# size of array 1000
# index 893
# size of array 1000
# index 893
# Hashed index 39
# size of array 1000
# index 39
# size of array 1000
# index 39
# Hashed index 942
# size of array 1000
# index 942
# size of array 1000
# index 942
# Hashed index 201
# size of array 1000
# index 201
# size of array 1000
# index 201
# Hashed index 932
# size of array 1000
# index 932
# size of array 1000
# index 932
# Hashed index 104
# size of array 1000
# index 104
# size of array 1000
# index 104
# Hashed index 337
# size of array 1000
# index 337
# size of array 1000
# index 337
# Hashed index 30
# size of array 1000
# index 30
# size of array 1000
# index 30
# Hashed index 112
# size of array 1000
# index 112
# size of array 1000
# index 112
# Hashed index 138
# size of array 1000
# index 138
# size of array 1000
# index 138
# Hashed index 589
# size of array 1000
# index 589
# size of array 1000
# index 589
# Hashed index 931
# size of array 1000
# index 931
# size of array 1000
# index 931
# Hashed index 158
# size of array 1000
# index 158
# size of array 1000
# index 158
# Hashed index 718
# size of array 1000
# index 718
# size of array 1000
# index 718
# Hashed index 814
# size of array 1000
# index 814
# size of array 1000
# index 814
# Hashed index 554
# size of array 1000
# index 554
# size of array 1000
# index 554
# Hashed index 505
# size of array 1000
# index 505
# size of array 1000
# index 505
# Hashed index 780
# size of array 1000
# index 780
# size of array 1000
# index 780
# Hashed index 451
# size of array 1000
# index 451
# size of array 1000
# index 451
# Hashed index 674
# size of array 1000
# index 674
# size of array 1000
# index 674
# Hashed index 940
# size of array 1000
# index 940
# size of array 1000
# index 940
# Hashed index 601
# size of array 1000
# index 601
# size of array 1000
# index 601
# Hashed index 399
# size of array 1000
# index 399
# size of array 1000
# index 399
# Hashed index 822
# size of array 1000
# index 822
# size of array 1000
# index 822
# Hashed index 337
# size of array 1000
# index 337
# size of array 1000
# index 337
# Hashed index 780
# size of array 1000
# index 780
# size of array 1000
# index 780
# Hashed index 901
# size of array 1000
# index 901
# size of array 1000
# index 901
# Hashed index 796
# size of array 1000
# index 796
# size of array 1000
# index 796
# Hashed index 289
# size of array 1000
# index 289
# size of array 1000
# index 289
# Hashed index 554
# size of array 1000
# index 554
# size of array 1000
# index 554
# Hashed index 813
# size of array 1000
# index 813
# size of array 1000
# index 813
# Hashed index 634
# size of array 1000
# index 634
# size of array 1000
# index 634
# Hashed index 544
# size of array 1000
# index 544
# size of array 1000
# index 544
# Hashed index 949
# size of array 1000
# index 949
# size of array 1000
# index 949
# Hashed index 853
# size of array 1000
# index 853
# size of array 1000
# index 853
# Hashed index 284
# size of array 1000
# index 284
# size of array 1000
# index 284
# Hashed index 959
# size of array 1000
# index 959
# size of array 1000
# index 959
# Hashed index 928
# size of array 1000
# index 928
# size of array 1000
# index 928
# Hashed index 848
# size of array 1000
# index 848
# size of array 1000
# index 848
# Hashed index 595
# size of array 1000
# index 595
# size of array 1000
# index 595
# Hashed index 369
# size of array 1000
# index 369
# size of array 1000
# index 369
# Hashed index 879
# size of array 1000
# index 879
# size of array 1000
# index 879
# Hashed index 203
# size of array 1000
# index 203
# size of array 1000
# index 203
# Hashed index 96
# size of array 1000
# index 96
# size of array 1000
# index 96
# Hashed index 486
# size of array 1000
# index 486
# size of array 1000
# index 486
# Hashed index 480
# size of array 1000
# index 480
# size of array 1000
# index 480
# Hashed index 742
# size of array 1000
# index 742
# size of array 1000
# index 742
# Hashed index 735
# size of array 1000
# index 735
# size of array 1000
# index 735
# Hashed index 298
# size of array 1000
# index 298
# size of array 1000
# index 298
# Hashed index 650
# size of array 1000
# index 650
# size of array 1000
# index 650
# Hashed index 449
# size of array 1000
# index 449
# size of array 1000
# index 449
# Hashed index 400
# size of array 1000
# index 400
# size of array 1000
# index 400
# Hashed index 374
# size of array 1000
# index 374
# size of array 1000
# index 374
# Hashed index 677
# size of array 1000
# index 677
# size of array 1000
# index 677
# Hashed index 732
# size of array 1000
# index 732
# size of array 1000
# index 732
# Hashed index 850
# size of array 1000
# index 850
# size of array 1000
# index 850
# Hashed index 960
# size of array 1000
# index 960
# size of array 1000
# index 960
# Hashed index 102
# size of array 1000
# index 102
# size of array 1000
# index 102
# Hashed index 480
# size of array 1000
# index 480
# size of array 1000
# index 480
# Hashed index 475
# size of array 1000
# index 475
# size of array 1000
# index 475
# Hashed index 592
# size of array 1000
# index 592
# size of array 1000
# index 592
# Hashed index 549
# size of array 1000
# index 549
# size of array 1000
# index 549
# Hashed index 889
# size of array 1000
# index 889
# size of array 1000
# index 889
# Hashed index 52
# size of array 1000
# index 52
# size of array 1000
# index 52
# Hashed index 579
# size of array 1000
# index 579
# size of array 1000
# index 579
# Hashed index 466
# size of array 1000
# index 466
# size of array 1000
# index 466
# Hashed index 55
# size of array 1000
# index 55
# size of array 1000
# index 55
# Hashed index 577
# size of array 1000
# index 577
# size of array 1000
# index 577
# Hashed index 582
# size of array 1000
# index 582
# size of array 1000
# index 582
# Hashed index 558
# size of array 1000
# index 558
# size of array 1000
# index 558
# Hashed index 385
# size of array 1000
# index 385
# size of array 1000
# index 385
# Hashed index 941
# size of array 1000
# index 941
# size of array 1000
# index 941
# Hashed index 382
# size of array 1000
# index 382
# size of array 1000
# index 382
# Hashed index 954
# size of array 1000
# index 954
# size of array 1000
# index 954
# Hashed index 685
# size of array 1000
# index 685
# size of array 1000
# index 685
# Hashed index 188
# size of array 1000
# index 188
# size of array 1000
# index 188
# Hashed index 272
# size of array 1000
# index 272
# size of array 1000
# index 272
# Hashed index 931
# size of array 1000
# index 931
# size of array 1000
# index 931
# Hashed index 400
# size of array 1000
# index 400
# size of array 1000
# index 400
# Hashed index 484
# size of array 1000
# index 484
# size of array 1000
# index 484
# Hashed index 500
# size of array 1000
# index 500
# size of array 1000
# index 500
# Hashed index 399
# size of array 1000
# index 399
# size of array 1000
# index 399
# Hashed index 611
# size of array 1000
# index 611
# size of array 1000
# index 611
# Hashed index 290
# size of array 1000
# index 290
# size of array 1000
# index 290
# Hashed index 232
# size of array 1000
# index 232
# size of array 1000
# index 232
# Hashed index 579
# size of array 1000
# index 579
# size of array 1000
# index 579
# Hashed index 785
# size of array 1000
# index 785
# size of array 1000
# index 785
# Hashed index 546
# size of array 1000
# index 546
# size of array 1000
# index 546
# Hashed index 532
# size of array 1000
# index 532
# size of array 1000
# index 532
# Hashed index 460
# size of array 1000
# index 460
# size of array 1000
# index 460
# Hashed index 599
# size of array 1000
# index 599
# size of array 1000
# index 599
# Hashed index 343
# size of array 1000
# index 343
# size of array 1000
# index 343
# Hashed index 503
# size of array 1000
# index 503
# size of array 1000
# index 503
# Hashed index 253
# size of array 1000
# index 253
# size of array 1000
# index 253
# Hashed index 308
# size of array 1000
# index 308
# size of array 1000
# index 308
# Hashed index 763
# size of array 1000
# index 763
# size of array 1000
# index 763
# Hashed index 187
# size of array 1000
# index 187
# size of array 1000
# index 187
# Hashed index 137
# size of array 1000
# index 137
# size of array 1000
# index 137
# Hashed index 708
# size of array 1000
# index 708
# size of array 1000
# index 708
# Hashed index 978
# size of array 1000
# index 978
# size of array 1000
# index 978
# Hashed index 313
# size of array 1000
# index 313
# size of array 1000
# index 313
# Hashed index 186
# size of array 1000
# index 186
# size of array 1000
# index 186
# Hashed index 987
# size of array 1000
# index 987
# size of array 1000
# index 987
# Hashed index 837
# size of array 1000
# index 837
# size of array 1000
# index 837
# Hashed index 540
# size of array 1000
# index 540
# size of array 1000
# index 540
# Hashed index 407
# size of array 1000
# index 407
# size of array 1000
# index 407
# Hashed index 737
# size of array 1000
# index 737
# size of array 1000
# index 737
# Hashed index 628
# size of array 1000
# index 628
# size of array 1000
# index 628
# Hashed index 783
# size of array 1000
# index 783
# size of array 1000
# index 783
# Hashed index 917
# size of array 1000
# index 917
# size of array 1000
# index 917
# Hashed index 887
# size of array 1000
# index 887
# size of array 1000
# index 887
# Hashed index 548
# size of array 1000
# index 548
# size of array 1000
# index 548
# Hashed index 36
# size of array 1000
# index 36
# size of array 1000
# index 36
# Hashed index 804
# size of array 1000
# index 804
# size of array 1000
# index 804
# Hashed index 530
# size of array 1000
# index 530
# size of array 1000
# index 530
# Hashed index 511
# size of array 1000
# index 511
# size of array 1000
# index 511
# Hashed index 651
# size of array 1000
# index 651
# size of array 1000
# index 651
# Hashed index 206
# size of array 1000
# index 206
# size of array 1000
# index 206
# Hashed index 424
# size of array 1000
# index 424
# size of array 1000
# index 424
# Hashed index 697
# size of array 1000
# index 697
# size of array 1000
# index 697
# Hashed index 223
# size of array 1000
# index 223
# size of array 1000
# index 223
# Hashed index 853
# size of array 1000
# index 853
# size of array 1000
# index 853
# Hashed index 856
# size of array 1000
# index 856
# size of array 1000
# index 856
# Hashed index 529
# size of array 1000
# index 529
# size of array 1000
# index 529
# Hashed index 819
# size of array 1000
# index 819
# size of array 1000
# index 819
# Hashed index 608
# size of array 1000
# index 608
# size of array 1000
# index 608
# Hashed index 975
# size of array 1000
# index 975
# size of array 1000
# index 975
# Hashed index 985
# size of array 1000
# index 985
# size of array 1000
# index 985
# Hashed index 825
# size of array 1000
# index 825
# size of array 1000
# index 825
# Hashed index 588
# size of array 1000
# index 588
# size of array 1000
# index 588
# Hashed index 562
# size of array 1000
# index 562
# size of array 1000
# index 562
# 820 μs ± 44.7 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit

python_dict = {}
python_dict['matin'] = 1
python_dict.get('matin')
# Out:
# 57.4 ns ± 2 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
my_dict['matin']
# Out:
# size of array 1000
# index 204
# 1

# %%
my_dict['omid'] = '09129276719'
# Out:
# Hashed index 819
# size of array 1000
# index 819

# %%
my_dict['omid']
# Out:
# size of array 1000
# index 819
# '09129276719'
